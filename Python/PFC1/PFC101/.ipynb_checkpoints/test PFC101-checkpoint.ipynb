# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_csv('./Nombre de pannes par jour.csv',sep=",")

# %%
df.head()
# Out:
#    Count of Ordre de travail  Year    Month  Day        Earliest Date
# 0                          1  2019  January    3  2019-01-03 00:00:00
# 1                          1  2019  January    4  2019-01-04 00:00:00
# 2                          1  2019  January    5  2019-01-05 00:00:00
# 3                          1  2019  January    7  2019-01-07 00:00:00
# 4                          1  2019  January    8  2019-01-08 00:00:00

# %%
df = df.drop('Year', axis=1)
df = df.drop('Month', axis=1)
df = df.drop('Day', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Count of Ordre de travail  372 non-null    int64
#  1   Earliest Date              372 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 5.9+ KB

# %%
df['Earliest Date'] = pd.to_datetime(df['Earliest Date'])

# %%
df.head()
# Out:
#    Count of Ordre de travail Earliest Date
# 0                          1    2019-01-03
# 1                          1    2019-01-04
# 2                          1    2019-01-05
# 3                          1    2019-01-07
# 4                          1    2019-01-08

# %%
df.tail()
# Out:
#      Count of Ordre de travail Earliest Date
# 367                          1    2022-02-17
# 368                          1    2022-02-20
# 369                          2    2022-02-22
# 370                          1    2022-02-23
# 371                          1    2022-03-04

# %%
df.to_csv('./Nombre_de_pannes_pfc101.csv', index=False,sep=";")

# %%
df=pd.read_csv('./Nombre_de_pannes_pfc101.csv',sep=";",index_col="Earliest Date", parse_dates=True)

# %%
df.head()
# Out:
#                Count of Ordre de travail
# Earliest Date
# 2019-01-03                             1
# 2019-01-04                             1
# 2019-01-05                             1
# 2019-01-07                             1
# 2019-01-08                             1

# %%
df=df.asfreq("D")
df.index
# Out:
# DatetimeIndex(['2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-12',
#                ...
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#                '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02',
#                '2022-03-03', '2022-03-04'],
#               dtype='datetime64[ns]', name='Earliest Date', length=1157, freq='D')

# %%
df=df.fillna(0)

# %%
df.to_csv('./Nombre_de_pannes_pfc101.csv', index=True,sep=";")

# %%
df=pd.read_csv('./Nombre_de_pannes_pfc101.csv',sep=";",index_col="Earliest Date", parse_dates=True)

# %%
df.tail()
# Out:
#                Count of Ordre de travail
# Earliest Date
# 2022-02-28                           0.0
# 2022-03-01                           0.0
# 2022-03-02                           0.0
# 2022-03-03                           0.0
# 2022-03-04                           1.0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
y = df['Count of Ordre de travail'].to_frame()

result_add = seasonal_decompose(y, model='additive',period = 52)

# Plot
plt.rcParams.update({'figure.figsize': (8,8)})
result_add.plot().suptitle('Additive Decompose', fontsize=1)
plt.show()

# %%
msk=(df.index <'2021-07-30')
df_train=df[msk].copy()
df_test=df[~msk].copy()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

acf_original = plot_acf(df_train)

pacf_original = plot_pacf(df_train)

# %%
from statsmodels.tsa.stattools import adfuller #ADF TEST palue below 0.05 
adf_test = adfuller(df_train)
print(f'p-value: {adf_test[1]}')
# Out:
# p-value: 5.34208684188965e-14

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df_train, order=(6,1,6))
model_fit = model.fit()
# Out:
# C:\Users\mahdi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\mahdi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\mahdi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\mahdi\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast_test = model_fit.forecast(len(df_test))

df['forecast_manual'] = [None]*len(df_train) + list(forecast_test)

df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
from sklearn.metrics import mean_absolute_error,r2_score, mean_squared_error

mae = mean_absolute_error(df_test, forecast_test)
r2= r2_score(df_test, forecast_test)
rmse = np.sqrt(mean_squared_error(df_test, forecast_test))

print(f'mae - manual: {mae}')
print(f'r2 - manual: {r2}')
print(f'rmse - manual: {rmse}')
# Out:
# mae - manual: 0.49084614247183417
# r2 - manual: -0.005287886188925839
# rmse - manual: 0.6149962792338397

# %%
import pmdarima as pm
auto_arima = pm.auto_arima(df_train, stepwise=False, seasonal=False)
auto_arima
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, suppress_warnings=True)

# %%
forecast_test_auto = auto_arima.predict(n_periods=len(df_test))
df['forecast_auto'] = [None]*len(df_train) + list(forecast_test_auto)

df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
mae = mean_absolute_error(df_test, forecast_test_auto)
r2= r2_score(df_test, forecast_test_auto)
rmse = np.sqrt(mean_squared_error(df_test, forecast_test_auto))

print(f'mae - auto: {mae}')
print(f'r2 - auto: {r2}')
print(f'rmse - auto: {rmse}')
# Out:
# mae - auto: 0.464422675156114
# r2 - auto: 0.001495096647315508
# rmse - auto: 0.6129179841934319

# %%
sarima= pm.auto_arima(df_train, m=7)

# %%
forecast_sarima = sarima.predict(n_periods=len(df_test))
df['forecast_sarima'] = [None]*len(df_train) + list(forecast_sarima)

df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
mae = mean_absolute_error(df_test, forecast_sarima)
r2= r2_score(df_test, forecast_sarima)
rmse = np.sqrt(mean_squared_error(df_test, forecast_sarima))

print(f'mae - sarima: {mae}')
print(f'r2 -  sarima: {r2}')
print(f'rmse - sarima: {rmse}')
# Out:
# mae - sarima: 0.49136133967412243
# r2 -  sarima: -0.005549852639228581
# rmse - sarima: 0.6150764044895265

# %%
x_train=df_train.drop(['Count of Ordre de travail'], axis=1)

# %%
x_test=df_test.drop(['Count of Ordre de travail'], axis=1)

# %%
y_train=df_train['Count of Ordre de travail']

# %%
y_test=df_test['Count of Ordre de travail']

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
ses= SimpleExpSmoothing(np.asarray(y_train))

# %%
ses_fit=ses.fit(optimized=True)
y_pred= ses_fit.forecast(len(df_test))

# %%
df.head()
# Out:
#                Count of Ordre de travail  forecast_manual  forecast_auto  \
# Earliest Date
# 2019-01-03                           1.0              NaN            NaN
# 2019-01-04                           1.0              NaN            NaN
# 2019-01-05                           1.0              NaN            NaN
# 2019-01-06                           0.0              NaN            NaN
# 2019-01-07                           1.0              NaN            NaN
#
#                forecast_sarima
# Earliest Date
# 2019-01-03                 NaN
# 2019-01-04                 NaN
# 2019-01-05                 NaN
# 2019-01-06                 NaN
# 2019-01-07                 NaN

# %%
df = df.drop('forecast_manual', axis=1)
df = df.drop('forecast_auto', axis=1)
df = df.drop('forecast_sarima', axis=1)

# %%
df['forecast_ses'] = [None]*len(df_train) + list(y_pred)

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score( y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))

print(f'mae - ses: {mae}')
print(f'r2 - ses: {r2}')
print(f'rmse - ses: {rmse}')
# Out:
# mae - ses: 0.490511870675048
# r2 - ses: -0.005175187795073644
# rmse - ses: 0.614961806006598

# %%
df=pd.read_csv('./Nombre_de_pannes_pfc101.csv',sep=";", parse_dates=True)

df['Earliest Date'] = pd.to_datetime(df['Earliest Date'])
msk=(df['Earliest Date']<'2021-07-30')
df_train=df[msk].copy()
df_test=df[~msk].copy()

# %%
df.head()
# Out:
#   Earliest Date  Count of Ordre de travail
# 0    2019-01-03                        1.0
# 1    2019-01-04                        1.0
# 2    2019-01-05                        1.0
# 3    2019-01-06                        0.0
# 4    2019-01-07                        1.0

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x_train=df_train.drop(['Count of Ordre de travail'], axis=1)
x_test=df_test.drop(['Count of Ordre de travail'], axis=1)
y_train=df_train['Count of Ordre de travail']
y_test=df_test['Count of Ordre de travail']

# %%
rfr=RandomForestRegressor(random_state=7)

# %%
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=7)

# %%
y_pred=rfr.predict(x_test)

# %%
df['forecast_rfr'] = [None]*len(df_train) + list(y_pred)
df.index = df['Earliest Date']
del df['Earliest Date']
df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error

mae = mean_absolute_error(y_test,y_pred)
r2= r2_score( y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))

print(f'mae - rfr: {mae}')
print(f'r2 - rfr: {r2}')
print(f'rmse - rfr: {rmse}')
# Out:
# mae - rfr: 0.30275229357798167
# r2 - rfr: -0.24362416107382545
# rmse - rfr: 0.6840247862883923

# %%
df=df.asfreq("D")
df.index
# Out:
# DatetimeIndex(['2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-12',
#                ...
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#                '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02',
#                '2022-03-03', '2022-03-04'],
#               dtype='datetime64[ns]', name='Earliest Date', length=1157, freq='D')

# %%
df=pd.read_csv('./Nombre_de_pannes_pfc101.csv', encoding='latin-1',sep=";",index_col="Earliest Date", parse_dates=True)
df=df.asfreq("D")
df.index
# Out:
# DatetimeIndex(['2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-12',
#                ...
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#                '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02',
#                '2022-03-03', '2022-03-04'],
#               dtype='datetime64[ns]', name='Earliest Date', length=1157, freq='D')

# %%
df.head()
# Out:
#                Count of Ordre de travail
# Earliest Date
# 2019-01-03                           1.0
# 2019-01-04                           1.0
# 2019-01-05                           1.0
# 2019-01-06                           0.0
# 2019-01-07                           1.0

# %%
df=df.fillna(0)

# %%
df = df.rename(columns={'Earliest Date': 'Date début', 'Count of Ordre de travail': 'Number of Orders'})

# %%
df.insert(0,'null','')
df['null'] = 0

# %%
df.head()
# Out:
#                null  Number of Orders
# Earliest Date
# 2019-01-03        0               1.0
# 2019-01-04        0               1.0
# 2019-01-05        0               1.0
# 2019-01-06        0               0.0
# 2019-01-07        0               1.0

# %%
msk=(df.index<'2021-07-30')
df_train=df[msk].copy()
df_test=df[~msk].copy()

# %%
x_train=df_train.drop(['Number of Orders'], axis=1)
x_test=df_test.drop(['Number of Orders'], axis=1)
y_train=df_train[['Number of Orders']]
y_test=df_test[['Number of Orders']]

# %%
from xgboost import XGBRegressor
xg_reg=XGBRegressor()
xg_fit=xg_reg.fit(x_train, y_train)

# %%
 y_pred=xg_fit.predict(x_test)
df['forecast_xgboost'] = [None]*len(df_train) + list(y_pred)
df = df.drop('null', axis=1)
df.plot()
# Out:
# <AxesSubplot:xlabel='Earliest Date'>

# %%
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error

mae = mean_absolute_error(y_test,y_pred)
r2= r2_score( y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))

print(f'mae - xg: {mae}')
print(f'r2 - xg: {r2}')
print(f'rmse - xg: {rmse}')
# Out:
# mae - xg: 0.5696475921420876
# r2 - xg: -0.09628070360168262
# rmse - xg: 0.6422263917388468
