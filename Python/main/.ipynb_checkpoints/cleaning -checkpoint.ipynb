# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_csv('./Datas.csv', encoding='latin-1',sep=";")
df.head()
# Out:
#   Ordre de travail Staut Ordre de travail                      Service  \
# 0         OT000001                clôturé                   ECP BEURRE
# 1         OT000002                clôturé                      ECP UHT
# 2         OT000003           en cours INV                    Poste URA
# 3         OT000011           en cours INV  Fuite huile machoire droite
# 4         OT000012                clôturé                   ELECTRIQUE
#
#                                Description   Equipment  \
# 0                                      NaN    GCULZ201
# 1                                      NaN    GCULZ103
# 2                                      NaN  ULPRPH0104
# 3                                      NaN  ULPRPH0104
# 4  Préparation les nouveaux têtes scellage  ULPRPS0204
#
#                      Nom Equipement date enregistrement Noeud Parent  \
# 0  Production  Beurre creme fraiche                 NaN       GCULZ2
# ...

# %%
df.isnull().sum()
# Out:
# Ordre de travail                 0
# Staut Ordre de travail           0
# Service                         42
# Description                    607
# Equipment                     9118
# Nom Equipement                9118
# date enregistrement          21146
# Noeud Parent                  9118
# Nom_parent                    9118
# Classification Equipement    15330
# Date début                    9118
# Date Fin                      9118
# Modèle OT                    25946
# Type OT                       9118
# dtype: int64

# %%
df = df.drop('Modèle OT', axis=1)
df = df.dropna(subset=['Date début'])
df.isnull().sum()
# Out:
# Ordre de travail                 0
# Staut Ordre de travail           0
# Service                         40
# Description                    606
# Equipment                        0
# Nom Equipement                   0
# date enregistrement          12028
# Noeud Parent                     0
# Nom_parent                       0
# Classification Equipement     6212
# Date début                       0
# Date Fin                         0
# Type OT                          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16828 entries, 0 to 25945
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ordre de travail           16828 non-null  object
#  1   Staut Ordre de travail     16828 non-null  object
#  2   Service                    16788 non-null  object
#  3   Description                16222 non-null  object
#  4   Equipment                  16828 non-null  object
#  5   Nom Equipement             16828 non-null  object
#  6   date enregistrement        4800 non-null   object
#  7   Noeud Parent               16828 non-null  object
#  8   Nom_parent                 16828 non-null  object
#  9   Classification Equipement  10616 non-null  object
#  10  Date début                 16828 non-null  object
#  11  Date Fin                   16828 non-null  object
#  12  Type OT                    16828 non-null  object
# dtypes: object(13)
# ...

# %%
df = df.dropna(subset=['Classification Equipement'])
df = df.dropna(subset=['Service'])
df.isnull().sum()
# Out:
# Ordre de travail                0
# Staut Ordre de travail          0
# Service                         0
# Description                   338
# Equipment                       0
# Nom Equipement                  0
# date enregistrement          6796
# Noeud Parent                    0
# Nom_parent                      0
# Classification Equipement       0
# Date début                      0
# Date Fin                        0
# Type OT                         0
# dtype: int64

# %%
df = df.drop('Description', axis=1)
df = df.drop('Staut Ordre de travail', axis=1)
df = df.drop('date enregistrement', axis=1)
df = df.drop('Date Fin', axis=1)
df = df.drop('Nom Equipement', axis=1)
df = df.drop('Nom_parent', axis=1)

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate records: {duplicate_count}")
# Out:
# Number of duplicate records: 103

# %%
df.drop_duplicates(inplace=True)

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate records: {duplicate_count}")
# Out:
# Number of duplicate records: 0

# %%
category_mapping = {
    'Mec': 'MECANIQUE',
    'mec': 'MECANIQUE',
    'MEC': 'MECANIQUE',
    'ELEC': 'ELECTRIQUE',
    'Elec': 'ELECTRIQUE',
    'ALIM': 'ALIM',
    'ENERG': 'ENERG',
    'ELECTRIQUE': 'ELECTRIQUE',
    'GC':'GC',
    'Qual' : 'Qual',
    'PROCESS':'PROCESS',
    'Trait':'Trait',
    '0':'0'
    
}
df['Classification Equipement'] = df['Classification Equipement'].map(category_mapping)
value_counts = df['Classification Equipement'].value_counts()
print(value_counts)
# Out:
# MECANIQUE     9554
# ELECTRIQUE     453
# ALIM           310
# ENERG          118
# GC              28
# Qual             8
# PROCESS          3
# Trait            2
# Name: Classification Equipement, dtype: int64

# %%
categories = df['Service'].unique()

for category in categories:
    print(category)
# Out:
# ECP BEURRE
# ECP UHT
# Poste URA
# Fuite huile machoire droite
# DT/YC (Réparation transpalette TC14)
# Fuite au niveau circuit acide
# élec*
# Changement bande a vise
# PROD
# DT/WISSEM
# DT/MEJDI
# DIVERS
# élec
# DT/MHM
# DT/SADOK
# JOINTS ROUGE
# méc
# ENERGETIQUE
# prod
# DT/YASSINE (Fuite huile au niveaux plongeurs)
# élec+méc
# dt/wissem
# DT/MOUNIB
# DT/OUSSAMA
# DT/YOUSSEF
# MECANIQUE
# Prod
# DT/SALANI
# DT/GHAMMAM
# dt/wajdi
# REPARATION FOURRAGE CHIBA
# dt/Abdelhamid
# ECP UHT A3flex
# CHANGEMENT FILTRES
# DT/HAMDI
# EPC Serrure bureau
# CHANGEMENT DISTRIBUTEUR
# DT/BTM (Réparation fuite + Fixation circuit de réfroidissement)
# DT/FREJ
# DT/MHM (Défaut filtre hydraulique)
# REVISION VANNE
# ELIMINATION FUITE VAPEUR
# CHANGEMENT LAME
# méc*
# CHANGEMENT CAPTEUR IFM
# CHANGEMENT CONTACTEUR
# EXTENSION CIRCUIT EAU CHAUDE
# CHANGEMENT JOINT ECHANGEUR
# DT/MAGASIN MC
# CHANGEMENT JOINT
# ECP-entretien vestiaire
# Extension(bureau de recherche)
# DT/ICHAOUI
# ...

# %%
df = df.drop('Service', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10476 entries, 0 to 25945
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ordre de travail           10476 non-null  object
#  1   Equipment                  10476 non-null  object
#  2   Noeud Parent               10476 non-null  object
#  3   Classification Equipement  10476 non-null  object
#  4   Date début                 10476 non-null  object
#  5   Type OT                    10476 non-null  object
# dtypes: object(6)
# memory usage: 572.9+ KB

# %%
df.head(5)
# Out:
#   Ordre de travail   Equipment Noeud Parent Classification Equipement  \
# 0         OT000001    GCULZ201       GCULZ2                 MECANIQUE
# 1         OT000002    GCULZ103       GCULZ1                 MECANIQUE
# 2         OT000003  ULPRPH0104     ULPRPH01                 MECANIQUE
# 3         OT000011  ULPRPH0104     ULPRPH01                 MECANIQUE
# 5         OT000015  ULPRDV0103     ULPRDV01                 MECANIQUE
#
#    Date début             Type OT
# 0  03/01/2019  correctif planifié
# 1  02/01/2019  correctif planifié
# 2  03/01/2019  correctif planifié
# 3  03/01/2019  correctif planifié
# 5  01/01/2019  correctif planifié

# %%
df.loc[df['Date début'] == '12/03/1203', 'Date début'] = '12/03/2021'
df.loc[df['Date début'] == '2019-01-03', 'Date début'] = '03/01/2019'

# %%
value_counts = df['Classification Equipement'].value_counts()
print(value_counts)
# Out:
# MECANIQUE     9554
# ELECTRIQUE     453
# ALIM           310
# ENERG          118
# GC              28
# Qual             8
# PROCESS          3
# Trait            2
# Name: Classification Equipement, dtype: int64

# %%
df = df[df['Classification Equipement'] == 'MECANIQUE']

value_counts = df['Classification Equipement'].value_counts()
print(value_counts)
# Out:
# MECANIQUE    9554
# Name: Classification Equipement, dtype: int64

# %%
df.to_csv('clean.csv', index=False, encoding='latin-1',sep=";")

# %%
df=pd.read_csv('./clean.csv', encoding='latin-1',sep=";")

# %%
df.shape
# Out:
# (9554, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9554 entries, 0 to 9553
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ordre de travail           9554 non-null   object
#  1   Equipment                  9554 non-null   object
#  2   Noeud Parent               9554 non-null   object
#  3   Classification Equipement  9554 non-null   object
#  4   Date début                 9554 non-null   object
#  5   Type OT                    9554 non-null   object
# dtypes: object(6)
# memory usage: 448.0+ KB

# %%
df['Date début'] = pd.to_datetime(df['Date début'], format='%d/%m/%Y')

# %%
df1=df.groupby(df['Date début']).size().reset_index(name='Number of Orders')

# %%
df1.head(20)
# Out:
#    Date début  Number of Orders
# 0  2017-12-07                 1
# 1  2018-12-19                 1
# 2  2018-12-22                 1
# 3  2018-12-28                 1
# 4  2018-12-30                 3
# 5  2018-12-31                 1
# 6  2019-01-01                 9
# 7  2019-01-02                 9
# 8  2019-01-03                15
# 9  2019-01-04                 8
# 10 2019-01-05                 7
# 11 2019-01-06                 8
# 12 2019-01-07                18
# 13 2019-01-08                12
# 14 2019-01-09                10
# 15 2019-01-10                13
# 16 2019-01-11                13
# 17 2019-01-12                55
# 18 2019-01-13                 6
# 19 2019-01-14                 6

# %%
df1.index = df1['Date début']
del df1['Date début']

# %%
plt.figure(figsize=(22, 15))
sns.lineplot(data=df1, x=df1.index, y=df1['Number of Orders'], linewidth=4)
# Out:
# <AxesSubplot:xlabel='Date début', ylabel='Number of Orders'>

# %%
df= df[df['Date début'] >'2018-12-31']
df.to_csv('clean.csv', index=False, encoding='latin-1',sep=";")

# %%
df1=df.groupby(df['Date début']).size().reset_index(name='Number of Orders')


df1.to_csv('nombre_depanes_par_jour.csv', index=False, encoding='latin-1',sep=";")

df1=pd.read_csv('./nombre_depanes_par_jour.csv', encoding='latin-1',sep=";",index_col="Date début", parse_dates=True)

# %%
df1.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2022-02-28', '2022-03-01', '2022-03-02', '2022-03-03',
#                '2022-03-04', '2022-03-05', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10'],
#               dtype='datetime64[ns]', name='Date début', length=1148, freq=None)

# %%
df1=df1.asfreq("D")
df1.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10'],
#               dtype='datetime64[ns]', name='Date début', length=1165, freq='D')

# %%
df1.isnull().sum()
# Out:
# Number of Orders    17
# dtype: int64

# %%
df1=df1.fillna(0)

# %%
df1.isnull().sum()
# Out:
# Number of Orders    0
# dtype: int64

# %%
df1.to_csv('nombre_depanes_par_jour.csv', index=True, encoding='latin-1',sep=";")

# %%
df1=pd.read_csv('./nombre_depanes_par_jour.csv', encoding='latin-1',sep=";",index_col="Date début", parse_dates=True)

# %%
df1=df1.asfreq("D")
df1.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05', '2022-03-06', '2022-03-07', '2022-03-08',
#                '2022-03-09', '2022-03-10'],
#               dtype='datetime64[ns]', name='Date début', length=1165, freq='D')

# %%
df1.head()
# Out:
#             Number of Orders
# Date début
# 2019-01-01               9.0
# 2019-01-02               9.0
# 2019-01-03              15.0
# 2019-01-04               8.0
# 2019-01-05               7.0

# %%
plt.figure(figsize=(22, 15))
sns.lineplot(data=df1, x=df1.index, y=df1['Number of Orders'], linewidth=4)
# Out:
# <AxesSubplot:xlabel='Date début', ylabel='Number of Orders'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

y = df1['Number of Orders'].to_frame()

result_add = seasonal_decompose(y, model='additive',period = 52)

# Plot
plt.rcParams.update({'figure.figsize': (8,8)})
result_add.plot().suptitle('Additive Decompose', fontsize=1)
plt.show()

# %%
df=df1
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1165 entries, 2019-01-01 to 2022-03-10
# Freq: D
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Number of Orders  1165 non-null   float64
# dtypes: float64(1)
# memory usage: 18.2 KB
#             Number of Orders
# Date début
# 2019-01-01               9.0
# 2019-01-02               9.0
# 2019-01-03              15.0
# 2019-01-04               8.0
# 2019-01-05               7.0

# %%
msk=(df.index <'2021-07-30')
df_train=df[msk].copy()
df_test=df[~msk].copy()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

acf_original = plot_acf(df_train)

pacf_original = plot_pacf(df_train)

# %%
from statsmodels.tsa.stattools import adfuller #ADF TEST palue below 0.05 
adf_test = adfuller(df_train)
print(f'p-value: {adf_test[1]}')
# Out:
# p-value: 0.00021323810196111965

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df_train, order=(7,1,7))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:       Number of Orders   No. Observations:                  941
# Model:                 ARIMA(7, 1, 7)   Log Likelihood               -2912.602
# Date:                Wed, 22 May 2024   AIC                           5855.203
# Time:                        11:50:04   BIC                           5927.891
# Sample:                    01-01-2019   HQIC                          5882.913
#                          - 07-29-2021
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6346      0.132     -4.818      0.000      -0.893      -0.376
# ar.L2         -1.0813      0.093    -11.592      0.000      -1.264      -0.898
# ar.L3         -0.5572      0.126     -4.437      0.000      -0.803      -0.311
# ...

# %%
import matplotlib.pyplot as plt
residuals = model_fit.resid[1:]
fig, ax = plt.subplots(1,2)
residuals.plot(title='Residuals', ax=ax[0])
residuals.plot(title='Density', kind='kde', ax=ax[1])
plt.show()

# %%
acf_res = plot_acf(residuals)

pacf_res = plot_pacf(residuals)

# %%
forecast_test = model_fit.forecast(len(df_test))

df['forecast_manual'] = [None]*len(df_train) + list(forecast_test)

df.plot()
# Out:
# <AxesSubplot:xlabel='Date début'>

# %%
import pmdarima as pm
auto_arima = pm.auto_arima(df_train, stepwise=False, seasonal=False)
auto_arima
# Out:
# ARIMA(order=(3, 1, 2), scoring_args={}, suppress_warnings=True)

# %%
auto_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  941
# Model:               SARIMAX(3, 1, 2)   Log Likelihood               -2981.674
# Date:                Wed, 22 May 2024   AIC                           5977.349
# Time:                        11:50:19   BIC                           6011.270
# Sample:                    01-01-2019   HQIC                          5990.280
#                          - 07-29-2021
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0035      0.005     -0.640      0.522      -0.014       0.007
# ar.L1          0.4435      0.296      1.497      0.134      -0.137       1.024
# ar.L2         -0.0897      0.048     -1.871      0.061      -0.184       0.004
# ...

# %%
forecast_test_auto = auto_arima.predict(n_periods=len(df_test))
df['forecast_auto'] = [None]*len(df_train) + list(forecast_test_auto)

df.plot()
# Out:
# <AxesSubplot:xlabel='Date début'>

# %%
from sklearn.metrics import mean_absolute_error,r2_score, mean_squared_error

mae = mean_absolute_error(df_test, forecast_test)
r2= r2_score(df_test, forecast_test)
rmse = np.sqrt(mean_squared_error(df_test, forecast_test))

print(f'mae - manual: {mae}')
print(f'r2 - manual: {r2}')
print(f'rmse - manual: {rmse}')
# Out:
# mae - manual: 4.1885814259650065
# r2 - manual: 0.05766104703277841
# rmse - manual: 6.625448636381615

# %%
mae = mean_absolute_error(df_test, forecast_test_auto)
r2= r2_score(df_test, forecast_test_auto)
rmse = np.sqrt(mean_squared_error(df_test, forecast_test_auto))

print(f'mae - auto: {mae}')
print(f'r2 - auto: {r2}')
print(f'rmse - auto: {rmse}')
# Out:
# mae - auto: 4.477631103597064
# r2 - auto: -0.09077792282985064
# rmse - auto: 7.128200210577031

# %%
sarima= pm.auto_arima(df_train, m=7)

# %%
sarima
# Out:
# ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(0, 0, 2, 7),
#       suppress_warnings=True, with_intercept=False)

# %%
sarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                  941
# Model:             SARIMAX(0, 1, 2)x(0, 0, 2, 7)   Log Likelihood               -2962.849
# Date:                           Wed, 22 May 2024   AIC                           5935.697
# Time:                                   11:51:11   BIC                           5959.927
# Sample:                               01-01-2019   HQIC                          5944.934
#                                     - 07-29-2021
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9341      0.034    -27.729      0.000      -1.000      -0.868
# ma.L2         -0.0546      0.033     -1.667      0.096      -0.119       0.010
# ...

# %%
forecast_sarima = sarima.predict(n_periods=len(df_test))
df['forecast_sarima'] = [None]*len(df_train) + list(forecast_sarima)

df.plot()
# Out:
# <AxesSubplot:xlabel='Date début'>

# %%
mae = mean_absolute_error(df_test, forecast_sarima)
r2= r2_score(df_test, forecast_sarima)
rmse = np.sqrt(mean_squared_error(df_test, forecast_sarima))

print(f'mae - sarima: {mae}')
print(f'r2 -  sarima: {r2}')
print(f'rmse - sarima: {rmse}')
# Out:
# mae - sarima: 4.507243184629988
# r2 -  sarima: -0.03371281124781955
# rmse - sarima: 6.939236177274856
